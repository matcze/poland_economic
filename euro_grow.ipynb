# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("world_gpd_grow.csv") 
df
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code  1960      1961      1962      1963       1964  \
# ...

# %%
eu_countries = ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal", "Romania", "Slovenia", "Spain", "Sweden"]
years = ["2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008","2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", '2020', "2021", "2022", "2023", "2024"]

# %%
df_poland = df[df["Country Name"] == "Poland"]
df_poland_cent = []
for year in years:
    df_poland_cent += df_poland[year].values.tolist()
df_poland_cent
# Out:
# [4.65633252988236,
#  1.23374464400356,
#  1.90119437968586,
#  3.52337117234833,
#  5.09079546409544,
#  3.26082274679216,
#  6.20210710934373,
#  6.7604478527626,
#  4.38377069274605,
#  2.61512859291683,
#  3.16892748258036,
#  5.25546256612796,
#  1.51178167644575,
#  0.684240607051805,
#  3.92050862390032,
#  4.43176700264478,
#  3.03117767594847,
#  5.15245773325907,
#  6.2458584723942,
#  4.58045817256199,
#  -2.03556882399977,
#  6.92718266052501,
#  5.25545697386036,
#  0.249610834017872,
#  2.9233880806669]

# %%
plt.figure(figsize=(11, 6))
plt.plot(years, df_poland_cent,  label="Poland", marker="s")


plt.xlabel("Year", fontsize=14, labelpad=10)
plt.ylabel("Percentage", fontsize=14, labelpad=14)
plt.title("Yearly Percentage Changes in Poland")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
dataset_2023 = df[["2023", "Country Name"]]
dataset_2024 = df[["2024", "Country Name"]]
euro_gdp_2023 = sorted([df.loc[df["Country Name"] == c, "2023"].values[0] for c in eu_countries])
euro_gdp_2024 = sorted([df.loc[df["Country Name"] == c, "2024"].values[0] for c in eu_countries])

# %%
plt.figure(figsize=(12, 6))
plt.bar(eu_countries, euro_gdp_2024, color='skyblue')

# Labels and formatting
plt.xlabel("Country", fontsize=14, labelpad=10)
plt.ylabel("Percentage", fontsize=14, labelpad=14)
plt.title("GDP grow of EU Countries in 2024", fontsize=16, pad=10)
plt.xticks(rotation=45, ha='right')
plt.grid(True, linestyle='--', alpha=0.6, axis='y')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(eu_countries, euro_gdp_2023, color='maroon')

# Labels and formatting
plt.xlabel("Country", fontsize=14, labelpad=10)
plt.ylabel("Percentage", fontsize=14, labelpad=14)
plt.title("GDP grow of EU Countries in 2023", fontsize=16, pad=10)
plt.xticks(rotation=45, ha='right')
plt.grid(True, linestyle='--', alpha=0.6, axis='y')
plt.tight_layout()
plt.show()
